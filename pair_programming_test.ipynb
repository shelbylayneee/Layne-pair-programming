# %%
import pair_programming

result = pair_programming.polar_to_cartesian(1,0)
print(result)

result2= pair_programming.polar_to_cartesian(1,3.14)
print(result2)

# I used 1=r and 0=theta and got x=1.0 and y=0.0 -> looks good!
# I used 1=r and pi=theta and got x=-1 and y=0.0 -> looks good!
# math looks good, but rounding only works if the user inputs the coordiates, not if its called in a function.
# Out:
# (1.0, 0.0)
# (-0.9999987317275395, 0.0015926529164868282)
